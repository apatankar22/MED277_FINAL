# %%
# !pip install openai
import time
import openai
import pandas as pd
from tqdm import tqdm
import os
from openai import OpenAI

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/summarized_data1.csv", on_bad_lines = 'skip').reset_index()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...
# Mounted at /content/drive

# %%
def summarize_report(r1, r2):
  query = "You're a medical expert; here are summaries for one patient: {}\n{}\n Can you determine the cause of readmission. Be very concise, try to be as technical as possible, use one sentence:".format(r1, r2)
  client = OpenAI(api_key="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")
  response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You summarize any text that is given to you."},
        {"role": "user", "content": query}
        ]
    )

  time.sleep(41)
  return response.choices[0].message.content

# %%
openai.api_key = "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"
tqdm.pandas()
df["CAUSES"] = ""
df["CAUSES"] = df.progress_apply(lambda i: summarize_report(i.Report1, i.Report2), axis = 1)
#t1 = """A 69-year-old male recently had a CABG. He felt a "click" when he coughed. He was short of breath with increasing fatigue and unable to do his daily chores. He had no known allergies to drugs."""
#t2 = """69-year-old male with recent history of CABG presented with sternal debridement and unstable stenotomy. New large presternal fluid collection is present, greatest in space between the topmost and secondmost plates."""
#summary = summarize_report(t1, t2)
# Out:
#   1%|          | 1/125 [00:03<06:14,  3.02s/it]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-3-310bd6290a85> in <cell line: 4>()
#       2 tqdm.pandas()
#       3 df["CAUSES"] = ""
# ----> 4 df["CAUSES"] = df.progress_apply(lambda i: summarize_report(i.Report1, i.Report2), axis = 1)
#       5 #t1 = """A 69-year-old male recently had a CABG. He felt a "click" when he coughed. He was short of breath with increasing fatigue and unable to do his daily chores. He had no known allergies to drugs."""
#       6 #t2 = """69-year-old male with recent history of CABG presented with sternal debridement and unstable stenotomy. New large presternal fluid collection is present, greatest in space between the topmost and secondmost plates."""
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
# ...

# %%
df.to_csv("/content/drive/My Drive/Colab Notebooks/causes1.csv", encoding='utf-8')
